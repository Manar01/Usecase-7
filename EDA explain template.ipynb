# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  Step 1: Loading the Data

# %%
# Load the dataset
print("Loading dataset from file...")
data_path = "final_data.csv"  # Ensure this file is in the same directory
data = pd.read_csv(data_path)
print("Data Loaded Successfully!")
# Out:
# Loading dataset from file...
# Data Loaded Successfully!

# %%
# Display basic info
print("\nDataset Info:")
data.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
# ...

# %%
# Show first rows
print("\nFirst 5 Rows:")
print(data.head(10))
# Out:
# First 5 Rows:
#                                      player               team  \
# 0        /david-de-gea/profil/spieler/59377  Manchester United
# 1       /jack-butland/profil/spieler/128899  Manchester United
# 2          /tom-heaton/profil/spieler/34130  Manchester United
# 3  /lisandro-martinez/profil/spieler/480762  Manchester United
# 4     /raphael-varane/profil/spieler/164770  Manchester United
# 5      /harry-maguire/profil/spieler/177907  Manchester United
# 6    /victor-lindelof/profil/spieler/184573  Manchester United
# 7         /phil-jones/profil/spieler/117996  Manchester United
# 8        /teden-mengi/profil/spieler/548470  Manchester United
# 9          /luke-shaw/profil/spieler/183288  Manchester United
#
#                 name              position  height   age  appearance  \
# 0       David de Gea            Goalkeeper   189.0  32.0         104
# 1       Jack Butland            Goalkeeper   196.0  30.0          15
# ...

# %%
# Show last rows
print("\Last 5 Rows:")
print(data.tail(10))
# Out:
# \Last 5 Rows:
#                                           player                      team  \
# 10744   /alessandro-lopane/profil/spieler/819840  Western Sydney Wanderers
# 10745    /brandon-borrello/profil/spieler/293592  Western Sydney Wanderers
# 10746        /amor-layouni/profil/spieler/208880  Western Sydney Wanderers
# 10747       /yeni-ngbakoto/profil/spieler/111053  Western Sydney Wanderers
# 10748    /jarrod-carluccio/profil/spieler/749273  Western Sydney Wanderers
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
#                      name                    position      height   age  \
# ...

# %% [markdown]
# #  Step 2: Data Profiling & Quality Checks
# We check for missing values, duplicates, and data types to ensure data integrity.

# %%
# Check missing values
print("\nMissing Values:")
print(data.isnull().sum())

# No null data
# Out:
# Missing Values:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
# Check duplicates
print("\nDuplicate Rows:", data.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# Summary statistics
data.describe()
# Out:
#              height           age    appearance         goals       assists  \
# count  10754.000000  10754.000000  10754.000000  10754.000000  10754.000000
# mean     181.240353     26.041903     36.407011      0.125554      0.086978
# std        6.969818      4.777629     26.526541      0.235585      0.143351
# min      156.000000     15.000000      0.000000      0.000000      0.000000
# 25%      176.000000     22.000000     12.000000      0.000000      0.000000
# 50%      181.240353     26.000000     35.000000      0.045969      0.040773
# 75%      186.000000     29.000000     59.000000      0.172263      0.133136
# max      206.000000     43.000000    107.000000     11.250000      4.000000
#
#        yellow cards  second yellow cards     red cards  goals conceded  \
# count  10754.000000         10754.000000  10754.000000    10754.000000
# mean       0.189757             0.004666      0.006826        0.131655
# ...

# %%
# Check data types
print("\nData Types:")
print(data.dtypes)
# Out:
# Data Types:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %% [markdown]
# #  Step 3: Data Cleaning & Feature Engineering
# We clean the data by handling missing values and encoding categorical variables.

# %%
# Remove Duplicates
print(f"Duplicate Rows Before Removal: {data.duplicated().sum()}")
data.drop_duplicates(inplace=True)
print(f"Duplicate Rows After Removal: {data.duplicated().sum()}")
# Out:
# Duplicate Rows Before Removal: 0
# Duplicate Rows After Removal: 0

# %%
# Handle Missing Values
print(f"Missing Values Before Handling:\n{data.isnull().sum()}")
data.dropna(inplace=True)  # Drop rows with missing values
print(f"Missing Values After Handling:\n{data.isnull().sum()}")
# Out:
# Missing Values Before Handling:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64
# Missing Values After Handling:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# ...

# %%
# Encoding categorical variables
data = pd.get_dummies(data, drop_first=True)

# %% [markdown]
# #  Step 4: Univariate Analysis
# We analyze individual features to understand their distributions.
# ### **1️ Categorical Variables** (Bar Charts, Frequency Tables)
# ### **2️ Numerical Variables** (Histograms, Boxplots)

# %%
# Categorical Variables Analysis
categorical_columns = data.select_dtypes(include=['object']).columns

for col in categorical_columns:
    print(f"\nAnalyzing Categorical Variable: {col}")
    print(data[col].value_counts())
    
    plt.figure(figsize=(8,4))
    sns.countplot(x=data[col])
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# A countplot helps us understand the frequency of each category,
# which is useful for identifying dominant categories and potential imbalances.

# %%
# Numerical Variables Analysis
numerical_columns = data.select_dtypes(include=[np.number]).columns

for col in numerical_columns:
    print(f"\nAnalyzing Numerical Variable: {col}")
    print(f"Mean: {data[col].mean():.2f}, Median: {data[col].median():.2f}, Std Dev: {data[col].std():.2f}")
    
    plt.figure(figsize=(8,4))
    sns.histplot(data[col], bins=30, kde=True)
    plt.title(f"Histogram of {col}")
    plt.show()

    # A histogram allows us to observe the distribution of the numerical variable,
    # whether it is normally distributed, skewed, or contains outliers.
    
    plt.figure(figsize=(8,4))
    sns.boxplot(x=data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

    # A boxplot helps detect outliers and provides insights on the spread of the data.
    # The box represents the interquartile range (middle 50% of the data), while points outside
    # the whiskers indicate potential outliers.
# Out:
# Analyzing Numerical Variable: height
# Mean: 181.24, Median: 181.24, Std Dev: 6.97
# Analyzing Numerical Variable: age
# Mean: 26.04, Median: 26.00, Std Dev: 4.78
# Analyzing Numerical Variable: appearance
# Mean: 36.41, Median: 35.00, Std Dev: 26.53
# Analyzing Numerical Variable: goals
# Mean: 0.13, Median: 0.05, Std Dev: 0.24
# Analyzing Numerical Variable: assists
# Mean: 0.09, Median: 0.04, Std Dev: 0.14
# Analyzing Numerical Variable: yellow cards
# Mean: 0.19, Median: 0.15, Std Dev: 0.43
# Analyzing Numerical Variable: second yellow cards
# Mean: 0.00, Median: 0.00, Std Dev: 0.03
# Analyzing Numerical Variable: red cards
# Mean: 0.01, Median: 0.00, Std Dev: 0.08
# Analyzing Numerical Variable: goals conceded
# Mean: 0.13, Median: 0.00, Std Dev: 0.44
# Analyzing Numerical Variable: clean sheets
# Mean: 0.04, Median: 0.00, Std Dev: 0.92
# Analyzing Numerical Variable: minutes played
# Mean: 2470.79, Median: 2101.50, Std Dev: 2021.70
# Analyzing Numerical Variable: days_injured
# ...

# %% [markdown]
# Step 5: Bivariate & Multivariate Analysis
# We analyze relationships between multiple variables.
# ### **Feature Relationships & Correlations**
# We check:
# - **Categorical vs. Categorical** (Stacked Bar Charts)
# - **Categorical vs. Numerical** (Boxplots, Scatterplots)
# - **Numerical vs. Numerical** (Scatterplots, Correlation Heatmaps)

# %%
# Correlation Matrix (Numerical Variables)
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# A heatmap helps visualize relationships between numerical features.
# Strong correlations (close to 1 or -1) indicate features that may be redundant,
# while weak correlations suggest independent variables.

# %%
# Categorical vs. Numerical Relationships
for col in numerical_columns:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=data[categorical_columns[0]], y=data[col])
    plt.title(f"Boxplot of {col} by {categorical_columns[0]}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Categorical vs. Numerical Relationships
# ----> 2 for col in numerical_columns:
#       3     plt.figure(figsize=(8,4))
#       4     sns.boxplot(x=data[categorical_columns[0]], y=data[col])
#
# NameError: name 'numerical_columns' is not defined

# %%
# This boxplot allows us to compare the distribution of a numerical 
# feature across different categories. Large variations in medians suggest a strong
# relationship between the categorical and numerical variables.

# %% [markdown]
# #  Step 6: Outlier Detection
# Detecting outliers to ensure data consistency. We check for extreme values using:
# - **Boxplots**
# - **Histograms**

# %%
# Outlier Detection
plt.figure(figsize=(12,6))
sns.boxplot(data=data.select_dtypes(include=[np.number]))
plt.title("Outlier Detection using Boxplot")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Outlier Detection
# ----> 2 plt.figure(figsize=(12,6))
#       3 sns.boxplot(data=data.select_dtypes(include=[np.number]))
#       4 plt.title("Outlier Detection using Boxplot")
#
# NameError: name 'plt' is not defined

# %%
# A boxplot summarizes the spread of numerical variables and helps us
# quickly identify outliers. Points that appear far from the whiskers are potential
# outliers that may need to be handled before modeling.

# %% [markdown]
# #  Step 7: Saving Cleaned Data
# We save the cleaned dataset for future use.

# %%
# Saving Cleaned Data
cleaned_data_path = "cleaned_final_data.csv"
data.to_csv(cleaned_data_path, index=False)
print(f"Cleaned dataset saved at: {cleaned_data_path}")

print("\nEDA Completed Successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Saving Cleaned Data
#       2 cleaned_data_path = "cleaned_final_data.csv"
# ----> 3 data.to_csv(cleaned_data_path, index=False)
#       4 print(f"Cleaned dataset saved at: {cleaned_data_path}")
#       6 print("\nEDA Completed Successfully!")
#
# File c:\Users\manar\anaconda3\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
updated_data = pd.read_csv("cleaned_final_data.csv")
updated_data.head()
